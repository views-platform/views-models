# %%
import numpy as np
import pickle

from matplotlib import pyplot as plt

from tensor_handler_00 import TensorPlotter
from tensor_handler_00 import TensorHandler

# %%
posterior_dict_path = "/home/simon/Documents/scripts/views_platform/views-models/models/purple_alien/data/generated/posterior_dict_36_calibration_20250219_062511.pkl"
meta_vol_path = "/home/simon/Documents/scripts/views_platform/views-models/models/purple_alien/data/generated/metadata_vol_36_calibration_20250219_062511.pkl"
with open(posterior_dict_path, "rb") as f:
    posterior_dict = pickle.load(f)
with open(meta_vol_path, "rb") as f:
    meta_vol = pickle.load(f)

# %%
zstack_combined_path = "/home/simon/Documents/scripts/views_platform/views-models/models/purple_alien/data/generated/zstack_combined_36_calibration_20250219_183705.pkl"

with open(zstack_combined_path, "rb") as f:
    zstack_combined = pickle.load(f)

# %%
zstack_combined.shape
# Out:
# (36, 180, 180, 11, 32)

# %%
# plot some imshows of each of the zstacks features

for i in range(zstack_combined.shape[3]):

    vmin = np.min(zstack_combined[0,:,:,i,0])
    vmax = np.max(zstack_combined[0,:,:,i,0])

    plt.imshow(zstack_combined[0,:,:,i,0], vmin= vmin, vmax=vmax) # just the first month and the first sample
    plt.colorbar()
    plt.title(f"Feature {i}")
    plt.show()
